# %%
pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\welcome\appdata\local\programs\python\python313\lib\site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\welcome\appdata\local\programs\python\python313\lib\site-packages (from wordcloud) (2.2.3)
# Requirement already satisfied: pillow in c:\users\welcome\appdata\local\programs\python\python313\lib\site-packages (from wordcloud) (11.1.0)
# Requirement already satisfied: matplotlib in c:\users\welcome\appdata\local\programs\python\python313\lib\site-packages (from wordcloud) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\welcome\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\welcome\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\welcome\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\welcome\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\welcome\appdata\roaming\python\python313\site-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\welcome\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\welcome\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\welcome\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import re


commentary = """The match was thrilling and exciting! The players showed great skill and determination. 
It was an intense battle between two strong teams."""
def clean_text(text):
    text = text.lower()  
    text = re.sub(r'[^\w\s]', '', text) 
    words = text.split()
    words = [word for word in words if word not in STOPWORDS]  
    return " ".join(words)
cleaned_text = clean_text(commentary)
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(cleaned_text)
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off") 
plt.show()
